# %%
from google.colab import files
import pandas as pd
import seaborn as sns

# Set Seaborn figure size
sns.set(rc={'figure.figsize': (5, 5)})

# Upload the 'airbnb.csv' file
uploaded = files.upload()

# Get the file name from the uploaded keys
file_name = list(uploaded.keys())[0]

try:
    # Load the data using pandas
    df_airbnb = pd.read_csv(file_name)

    # Display the first five rows of the DataFrame
    print(df_airbnb.head(5))

except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found in the /content/ directory.")
except Exception as e:
    print(f"An error occurred while loading the file: {str(e)}")
# Out:
#      <input type="file" id="files-4a657d5e-168b-4b92-a590-f793516b7eab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a657d5e-168b-4b92-a590-f793516b7eab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print("Shape of the DataFrame: ", df_airbnb.shape)
# Out:
# Shape of the DataFrame:  (48895, 16)

# %%
print(df_airbnb.head())
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
print(df_airbnb.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df_airbnb["name"].value_counts()
# Out:
# Hillside Hotel                                        18
# Home away from home                                   17
# New york Multi-unit building                          16
# Brooklyn Apartment                                    12
# Loft Suite @ The Box House Hotel                      11
#                                                       ..
# Large 1BR Apt. in Williamsburg                         1
# Feel at Home                                           1
# Spacious Modern Alcove Studio in a Luxury Building     1
# Artist's Room in Large Apartment                       1
# Trendy duplex in the very heart of Hell's Kitchen      1
# Name: name, Length: 47905, dtype: int64

# %%
df_airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df_airbnb.describe().T
# Out:
#                                   count          mean           std  \
# id                              48895.0  1.901714e+07  1.098311e+07
# host_id                         48895.0  6.762001e+07  7.861097e+07
# latitude                        48895.0  4.072895e+01  5.453008e-02
# longitude                       48895.0 -7.395217e+01  4.615674e-02
# price                           48895.0  1.527207e+02  2.401542e+02
# minimum_nights                  48895.0  7.029962e+00  2.051055e+01
# number_of_reviews               48895.0  2.327447e+01  4.455058e+01
# reviews_per_month               38843.0  1.373221e+00  1.680442e+00
# calculated_host_listings_count  48895.0  7.143982e+00  3.295252e+01
# availability_365                48895.0  1.127813e+02  1.316223e+02
#
#                                        min           25%           50%  \
# id                              2539.00000  9.471945e+06  1.967728e+07
# host_id                         2438.00000  7.822033e+06  3.079382e+07
# ...

# %%
from os import mkdir

# %%
try:
  mkdir("Plots")
except:
  pass

mypaths="Plots"

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6e0bdfc06d43> in <cell line: 7>()
#       5 # Upload the 'airbnb.csv' file in Google Colab
#       6 from google.colab import files
# ----> 7 uploaded = files.upload()
#       8
#       9 # Load the data using pandas (no need to specify the path)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in upload()
#      67   """
#      68
# ---> 69   uploaded_files = _upload_files(multiple=True)
#      70   # Mapping from original filename to filename as saved locally.
#      71   local_filenames = dict()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in _upload_files(multiple)
#     161   files = _collections.defaultdict(bytes)
#     162
# --> 163   while result['action'] != 'complete':
#     164     result = _output.eval_js(
# ...

# %%
df_airbnb[["name","latitude"]]
# Out:
#                                                     name  latitude
# 0                     Clean & quiet apt home by the park  40.64749
# 1                                  Skylit Midtown Castle  40.75362
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  40.80902
# 3                        Cozy Entire Floor of Brownstone  40.68514
# 4       Entire Apt: Spacious Studio/Loft by central park  40.79851
# ...                                                  ...       ...
# 48890    Charming one bedroom - newly renovated rowhouse  40.67853
# 48891      Affordable room in Bushwick/East Williamsburg  40.70184
# 48892            Sunny Studio at Historical Neighborhood  40.81475
# 48893               43rd St. Time Square-cozy single bed  40.75751
# 48894  Trendy duplex in the very heart of Hell's Kitchen  40.76404
#
# [48895 rows x 2 columns]

# %%
[df_airbnb["price"] < 500]
# Out:
# [0        True
#  1        True
#  2        True
#  3        True
#  4        True
#           ...
#  48890    True
#  48891    True
#  48892    True
#  48893    True
#  48894    True
#  Name: price, Length: 48895, dtype: bool]

# %%
df_airbnb["name"].value_counts()
# Out:
# Hillside Hotel                                        18
# Home away from home                                   17
# New york Multi-unit building                          16
# Brooklyn Apartment                                    12
# Loft Suite @ The Box House Hotel                      11
#                                                       ..
# Large 1BR Apt. in Williamsburg                         1
# Feel at Home                                           1
# Spacious Modern Alcove Studio in a Luxury Building     1
# Artist's Room in Large Apartment                       1
# Trendy duplex in the very heart of Hell's Kitchen      1
# Name: name, Length: 47905, dtype: int64

# %%
df_airbnb["latitude"].index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %%
sns.barplot(x="name", y=df_airbnb["price"].index, data=df_airbnb, color="purple").set_title("Price category")

# %%
import matplotlib.pyplot as plt

# %%
df_airbnb.to_csv('umair_airbnb.csv', index=False)
